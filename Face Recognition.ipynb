# %%
#for creating csv files and creation of collections in localhost.
import os
import pandas
from datetime import *
from csv import *
import csv
from pymongo import MongoClient
date=str(date.today().strftime("%d-%m-%Y"))
if((os.path.isfile(date+'_Attendance.csv'))==False):
    df=pandas.DataFrame(columns=('Roll Number', 'Department','Time'))
    df.to_csv(date+'_Attendance.csv',',',index=False)
filename=date+'_Attendance.csv'
def markAttendance(name):
    datetoday=str(date.today().strftime("%d-%m-%Y"))
    connection = MongoClient("localhost", 27017)
    database = connection['Attendance']
    data=database[datetoday+'_Attendance']
    i=1
    file = open(filename)
    csvreader = csv.reader(file)
    for row in csvreader:
        if(name in row):
            i=0
    file.close()
    if(i):
        with open(filename, 'a',newline='') as att:
            writer_object = writer(att)
            writer_object.writerow([name,'IT',datetime.now()])
            att.close()
            value={"Name":name,"Department":"IT","Time":datetime.now()}
            x=data.insert_one(value)

# %%
#for creating csv files and creation of collections in Atlas.
import os
import pandas
from datetime import *
from csv import *
import csv
from pymongo import MongoClient
date=str(date.today().strftime("%d-%m-%Y"))
if((os.path.isfile(date+'_Attendance.csv'))==False):
    df=pandas.DataFrame(columns=('Roll Number', 'Department','Time'))
    df.to_csv(date+'_Attendance.csv',',',index=False)
filename=date+'_Attendance.csv'
username=input("Enter Username ")
password=input('Enter Password ')
connection = MongoClient('mongodb+srv://'+username+':'+password+'@cluster0.f58i3.mongodb.net/myFirstDatabase?retryWrites=true&w=majority')
def markAttendance(name):
    datetoday=str(date.today().strftime("%d-%m-%Y"))
    database = connection['Attendance']
    data=database[datetoday+'_Attendance']
    i=1
    file = open(filename)
    csvreader = csv.reader(file)
    for row in csvreader:
        if(name in row):
            i=0
    file.close()
    if(i):
        with open(filename, 'a',newline='') as att:
            writer_object = writer(att)
            writer_object.writerow([name,'IT',datetime.now()])
            att.close()
            value={"Name":name,"Department":"IT","Time":datetime.now()}
            x=data.insert_one(value)
# Out:
# Enter Username User
# Enter Password User

# %%
#for live webcam and displaying names on it.
import json
import cv2
import numpy as np
import face_recognition
import os
from datetime import *
import time
import sys
data = json.loads(open('data.json', "rb").read())

encodeListKnown=data['encodings']
classNames=data['names']
cap = cv2.VideoCapture(0)

while True:
    success, img = cap.read()
    imgS = cv2.resize(img, (0, 0), None, 0.25, 0.25)
    imgS = cv2.cvtColor(imgS, cv2.COLOR_BGR2RGB)

    facesCurFrame = face_recognition.face_locations(imgS)
    encodesCurFrame = face_recognition.face_encodings(imgS, facesCurFrame)
    for encodeFace, faceLoc in zip(encodesCurFrame, facesCurFrame):
        matches = face_recognition.compare_faces(encodeListKnown, encodeFace,0.45)
        if(matches.count(True)>0):
            matchIndex=matches.index(True)
            if matches[matchIndex]:
                name = classNames[matchIndex].upper()
                y1, x2, y2, x1 = faceLoc
                y1, x2, y2, x1 = y1 * 4, x2 * 4, y2 * 4, x1 * 4
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.rectangle(img, (x1, y2 - 35), (x2, y2), (0, 255, 0), -1)
                cv2.putText(img, name, (x1 + 6, y2 - 6), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2)
                markAttendance(name)
        else:
            continue
    cv2.imshow('Webcam', img)
    cv2.waitKey(1)

# %%
#for live webcam and displaying names on it.
import json
import cv2
import numpy as np
import face_recognition
import os
from datetime import *
import time
import sys
data = json.loads(open('data.json', "rb").read())

encodeListKnown=data['encodings']
classNames=data['names']
cap = cv2.VideoCapture(0)

while True:
    success, img = cap.read()
    imgS = cv2.resize(img, (0, 0), None, 0.25, 0.25)
    imgS = cv2.cvtColor(imgS, cv2.COLOR_BGR2RGB)

    facesCurFrame = face_recognition.face_locations(imgS)
    encodesCurFrame = face_recognition.face_encodings(imgS, facesCurFrame)
    for encodeFace, faceLoc in zip(encodesCurFrame, facesCurFrame):
        matches = face_recognition.compare_faces(encodeListKnown, encodeFace,0.45)
        faceDis = face_recognition.face_distance(encodeListKnown, encodeFace)
        print(matches)
        print(faceDis)
        matchIndex = np.argmin(faceDis)
        if matches[matchIndex]:
            name = classNames[matchIndex].upper()
            y1, x2, y2, x1 = faceLoc
            y1, x2, y2, x1 = y1 * 4, x2 * 4, y2 * 4, x1 * 4
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.rectangle(img, (x1, y2 - 35), (x2, y2), (0, 255, 0), cv2.FILLED)
            cv2.putText(img, name, (x1 + 6, y2 - 6), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2)
            markAttendance(name)
    cv2.imshow('Webcam', img)
    cv2.waitKey(1)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# [0.76225645 0.71220297 0.73355746 0.70554967 0.65251658 0.65761435
#  0.62297524 0.45845144 0.67829721 0.66881495 0.70941058 0.71528736
#  0.7646524  0.65310649 0.69470488]
# [False, False, False, False, False, False, False, True, False, False, False, False, False, False, False]
# [0.76334273 0.72397368 0.67897631 0.61005317 0.64802487 0.64142557
#  0.68181603 0.39540589 0.61351263 0.6071671  0.62331572 0.72148387
#  0.70092098 0.66424212 0.63522056]
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# [0.78623247 0.71331751 0.71147372 0.68868423 0.70155742 0.70954796
#  0.73134307 0.50693334 0.69686412 0.69439316 0.67426332 0.73756357
#  0.77280312 0.65583515 0.67991633]
# [False, False, False, False, False, False, False, True, False, False, False, False, False, False, False]
# ...
